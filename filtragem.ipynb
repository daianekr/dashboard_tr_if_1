# %%
import pandas as pd 
import numpy as np
import plotly.express as px
import plotly.graph_objs as go

# %%
df = pd.read_csv("Dados_2012_1_2023_1_DC.csv", sep=",")

# %%
df.head()
# Out:
#       Instituição                               Nome do Curso Semestre Início  \
# 0  Campus Aracruz  BAQUIN - Bacharelado em Química Industrial          2016/1
# 1  Campus Aracruz  BAQUIN - Bacharelado em Química Industrial          2016/1
# 2  Campus Aracruz  BAQUIN - Bacharelado em Química Industrial          2016/1
# 3  Campus Aracruz  BAQUIN - Bacharelado em Química Industrial          2016/1
# 4  Campus Aracruz  BAQUIN - Bacharelado em Química Industrial          2016/1
#
#   Semestre Fim   Forma de Ingresso Situação da Matrícula Tempo Sexo
# 0       2016/2     Ação Afirmativa               Evadido     1    M
# 1       2016/2  Ampla Concorrência               Evadido     1    M
# 2       2016/2  Ampla Concorrência               Evadido     1    M
# 3       2016/2  Ampla Concorrência               Evadido     1    F
# 4       2018/1  Ampla Concorrência               Evadido   2,5    M

# %%
df['Nome do Curso - Sem Código'] = df['Nome do Curso'].str.split(' - ').str[1]

# %%
df.head()
# Out:
#       Instituição                               Nome do Curso Semestre Início  \
# 0  Campus Aracruz  BAQUIN - Bacharelado em Química Industrial          2016/1
# 1  Campus Aracruz  BAQUIN - Bacharelado em Química Industrial          2016/1
# 2  Campus Aracruz  BAQUIN - Bacharelado em Química Industrial          2016/1
# 3  Campus Aracruz  BAQUIN - Bacharelado em Química Industrial          2016/1
# 4  Campus Aracruz  BAQUIN - Bacharelado em Química Industrial          2016/1
#
#   Semestre Fim   Forma de Ingresso Situação da Matrícula Tempo Sexo  \
# 0       2016/2     Ação Afirmativa               Evadido     1    M
# 1       2016/2  Ampla Concorrência               Evadido     1    M
# 2       2016/2  Ampla Concorrência               Evadido     1    M
# 3       2016/2  Ampla Concorrência               Evadido     1    F
# 4       2018/1  Ampla Concorrência               Evadido   2,5    M
#
#           Nome do Curso - Sem Código
# 0  Bacharelado em Química Industrial
# ...

# %%
df['Nome do Curso - Sem Código'].value_counts()
# Out:
# Nome do Curso - Sem Código
# Sistemas de Informação                                     1405
# Engenharia Mecânica                                        1247
# Licenciatura em Letras                                     1237
# Bacharelado em Administração                               1200
# Licenciatura em Letras Português                           1188
# Complementação Pedagógica                                  1141
# Agronomia                                                  1042
# Licenciatura em Química                                    1003
# Licenciatura em Matemática                                  992
# Engenharia de Controle e Automação                          973
# Licenciatura em Informática EAD                             740
# Bacharelado em Química Industrial                           661
# Tecnologia em Análise e Desenvolvimento de Sistemas EAD     627
# Engenharia de Produção                                      556
# ...

# %%
y=df[df['Sexo'] == 'M']

y
# Out:
#                                              Instituição  \
# 0                                         Campus Aracruz
# 1                                         Campus Aracruz
# 2                                         Campus Aracruz
# 4                                         Campus Aracruz
# 6                                         Campus Aracruz
# ...                                                  ...
# 24576                                     Campus Vitória
# 24578                                     Campus Vitória
# 24579                                     Campus Vitória
# 24589                                     Campus Vitória
# 24590  Centro de Referência em Formação e em Educação...
#
#                                            Nome do Curso Semestre Início  \
# 0             BAQUIN - Bacharelado em Química Industrial          2016/1
# 1             BAQUIN - Bacharelado em Química Industrial          2016/1
# ...

# %%
x=df.loc[(df['Instituição']=='Campus Aracruz') & (df['Nome do Curso - Sem Código'] == 'Bacharelado em Química Industrial')]

# %%
# !pip install nbformat

# %%
fig = go.Figure(
    data=[
        go.Bar(x=x, y=df[df['Sexo'] == 'F'], name="Feminino"),
        go.Bar(x=x, y=df[df['Sexo'] == 'M'], name="Masculino")
    ],
    layout=dict(
        barcornerradius=15,
    ),
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 11
#       1 fig = go.Figure(
#       2     data=[
#       3         go.Bar(x=x, y=df[df['Sexo'] == 'F'], name="Feminino"),
#    (...)
#       8     ),
#       9 )
# ---> 11 fig.show()
#
# File ~/dashboard_tr_if_1/venv_if/lib/python3.12/site-packages/plotly/basedatatypes.py:3410, in BaseFigure.show(self, *args, **kwargs)
#    3377 """
#    3378 Show a figure using either the default renderer(s) or the renderer(s)
#    3379 specified by the renderer argument
#    (...)
#    3406 None
#    3407 """
#    3408 import plotly.io as pio
# -> 3410 return pio.show(self, *args, **kwargs)
#
# File ~/dashboard_tr_if_1/venv_if/lib/python3.12/site-packages/plotly/io/_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
# ...
